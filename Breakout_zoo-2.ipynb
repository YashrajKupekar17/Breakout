# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-qs13c6qf
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-qs13c6qf
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 06ab06238933b151dd62d8a39dd344d4cfcaf7c1
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.6.0a2 (from rl_zoo3==2.6.0a2)
#   Downloading sb3_contrib-2.6.0a2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0a2) (1.1.1)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.6.0a2)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0a2) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0a2) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.6.0a2)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.6.0a2) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.6.0a2)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.6.0a2)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0a2) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0a2) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0a2) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.6.0a2) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (0.28.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.6.0a2)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.6.0a2)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.6.0a2) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.6.0a2) (2.0.39)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.6.0a2) (75.1.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading pathvalidate-3.2.3-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0a2)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.6.0a2 (from sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading stable_baselines3-2.6.0a2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.6.0a2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.6.0a2) (2.18.0)
# Collecting Mako (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.6.0a2)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (2.32.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.6.0a2) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.6.0a2) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.6.0a2) (3.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0a2) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0a2) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.6.0a2) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.6.0a2) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (3.2.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.6.0a2->sb3_contrib<3.0,>=2.6.0a2->rl_zoo3==2.6.0a2) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.6.0a2) (2025.1.31)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 11.1 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 10.1 MB/s eta 0:00:00
# Downloading sb3_contrib-2.6.0a2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 9.7 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 22.2 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.2.3-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.6.0a2-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 20.5 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.0 MB/s eta 0:00:00
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.6.0a2-py3-none-any.whl size=77702 sha256=5abba951e6e2c176b80b7efdc9f9503c0cc6cbfb7b316ebe9ef9c2ed98ae9b85
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8epwpkyg/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, Mako, colorlog, typepy, shimmy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, optuna, nvidia-cusolver-cu12, huggingface_sb3, DataProperty, tabledata, stable_baselines3, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed DataProperty-1.1.0 Mako-1.3.9 alembic-1.15.1 colorlog-6.9.0 huggingface_sb3-3.0 mbstrdecoder-1.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.2.1 pathvalidate-3.2.3 pytablewriter-1.2.1 rl_zoo3-2.6.0a2 sb3_contrib-2.6.0a2 shimmy-2.0.0 stable_baselines3-2.6.0a2 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,026 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 125044 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.10.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# !python -m rl_zoo3.train --algo dqn --env ALE/Breakout-v5  -f logs/  -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 209749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 31.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35812    |
# |    fps              | 166      |
# |    time_elapsed     | 5630     |
# |    total_timesteps  | 939168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 209791   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35816    |
# |    fps              | 166      |
# |    time_elapsed     | 5631     |
# |    total_timesteps  | 939340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0458   |
# |    n_updates        | 209834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 31.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35820    |
# |    fps              | 166      |
# |    time_elapsed     | 5632     |
# |    total_timesteps  | 939513   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 209878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 31.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35824    |
# |    fps              | 166      |
# |    time_elapsed     | 5634     |
# |    total_timesteps  | 939777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0727   |
# |    n_updates        | 209944   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35828    |
# |    fps              | 166      |
# |    time_elapsed     | 5635     |
# |    total_timesteps  | 940001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.115    |
# |    n_updates        | 210000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35832    |
# |    fps              | 166      |
# |    time_elapsed     | 5636     |
# |    total_timesteps  | 940210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 210052   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35836    |
# |    fps              | 166      |
# |    time_elapsed     | 5638     |
# |    total_timesteps  | 940435   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0636   |
# |    n_updates        | 210108   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35840    |
# |    fps              | 166      |
# |    time_elapsed     | 5638     |
# |    total_timesteps  | 940563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0578   |
# |    n_updates        | 210140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35844    |
# |    fps              | 166      |
# |    time_elapsed     | 5639     |
# |    total_timesteps  | 940735   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0635   |
# |    n_updates        | 210183   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35848    |
# |    fps              | 166      |
# |    time_elapsed     | 5640     |
# |    total_timesteps  | 940893   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0536   |
# |    n_updates        | 210223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35852    |
# |    fps              | 166      |
# |    time_elapsed     | 5641     |
# |    total_timesteps  | 941091   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0601   |
# |    n_updates        | 210272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35856    |
# |    fps              | 166      |
# |    time_elapsed     | 5642     |
# |    total_timesteps  | 941248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 210311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35860    |
# |    fps              | 166      |
# |    time_elapsed     | 5643     |
# |    total_timesteps  | 941419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 210354   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35864    |
# |    fps              | 166      |
# |    time_elapsed     | 5645     |
# |    total_timesteps  | 941619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 210404   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35868    |
# |    fps              | 166      |
# |    time_elapsed     | 5646     |
# |    total_timesteps  | 941849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0487   |
# |    n_updates        | 210462   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35872    |
# |    fps              | 166      |
# |    time_elapsed     | 5647     |
# |    total_timesteps  | 942061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0547   |
# |    n_updates        | 210515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35876    |
# |    fps              | 166      |
# |    time_elapsed     | 5648     |
# |    total_timesteps  | 942244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0818   |
# |    n_updates        | 210560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35880    |
# |    fps              | 166      |
# |    time_elapsed     | 5649     |
# |    total_timesteps  | 942386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 210596   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35884    |
# |    fps              | 166      |
# |    time_elapsed     | 5650     |
# |    total_timesteps  | 942541   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0669   |
# |    n_updates        | 210635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35888    |
# |    fps              | 166      |
# |    time_elapsed     | 5651     |
# |    total_timesteps  | 942755   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 210688   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35892    |
# |    fps              | 166      |
# |    time_elapsed     | 5653     |
# |    total_timesteps  | 942979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 210744   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35896    |
# |    fps              | 166      |
# |    time_elapsed     | 5654     |
# |    total_timesteps  | 943231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 210807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35900    |
# |    fps              | 166      |
# |    time_elapsed     | 5655     |
# |    total_timesteps  | 943346   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 210836   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35904    |
# |    fps              | 166      |
# |    time_elapsed     | 5656     |
# |    total_timesteps  | 943512   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 210877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35908    |
# |    fps              | 166      |
# |    time_elapsed     | 5657     |
# |    total_timesteps  | 943698   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 210924   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35912    |
# |    fps              | 166      |
# |    time_elapsed     | 5658     |
# |    total_timesteps  | 943822   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 210955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35916    |
# |    fps              | 166      |
# |    time_elapsed     | 5659     |
# |    total_timesteps  | 944003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 211000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35920    |
# |    fps              | 166      |
# |    time_elapsed     | 5660     |
# |    total_timesteps  | 944206   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 211051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35924    |
# |    fps              | 166      |
# |    time_elapsed     | 5661     |
# |    total_timesteps  | 944375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0503   |
# |    n_updates        | 211093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35928    |
# |    fps              | 166      |
# |    time_elapsed     | 5662     |
# |    total_timesteps  | 944551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 211137   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35932    |
# |    fps              | 166      |
# |    time_elapsed     | 5663     |
# |    total_timesteps  | 944744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 211185   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35936    |
# |    fps              | 166      |
# |    time_elapsed     | 5664     |
# |    total_timesteps  | 944893   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0475   |
# |    n_updates        | 211223   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35940    |
# |    fps              | 166      |
# |    time_elapsed     | 5665     |
# |    total_timesteps  | 945080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0674   |
# |    n_updates        | 211269   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35944    |
# |    fps              | 166      |
# |    time_elapsed     | 5666     |
# |    total_timesteps  | 945240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0568   |
# |    n_updates        | 211309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35948    |
# |    fps              | 166      |
# |    time_elapsed     | 5667     |
# |    total_timesteps  | 945386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0374   |
# |    n_updates        | 211346   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35952    |
# |    fps              | 166      |
# |    time_elapsed     | 5669     |
# |    total_timesteps  | 945700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0828   |
# |    n_updates        | 211424   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35956    |
# |    fps              | 166      |
# |    time_elapsed     | 5670     |
# |    total_timesteps  | 945901   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0533   |
# |    n_updates        | 211475   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35960    |
# |    fps              | 166      |
# |    time_elapsed     | 5671     |
# |    total_timesteps  | 946060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0454   |
# |    n_updates        | 211514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35964    |
# |    fps              | 166      |
# |    time_elapsed     | 5672     |
# |    total_timesteps  | 946245   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0656   |
# |    n_updates        | 211561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35968    |
# |    fps              | 166      |
# |    time_elapsed     | 5673     |
# |    total_timesteps  | 946414   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0703   |
# |    n_updates        | 211603   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35972    |
# |    fps              | 166      |
# |    time_elapsed     | 5674     |
# |    total_timesteps  | 946555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0506   |
# |    n_updates        | 211638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35976    |
# |    fps              | 166      |
# |    time_elapsed     | 5675     |
# |    total_timesteps  | 946827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 211706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35980    |
# |    fps              | 166      |
# |    time_elapsed     | 5676     |
# |    total_timesteps  | 946937   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 211734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35984    |
# |    fps              | 166      |
# |    time_elapsed     | 5677     |
# |    total_timesteps  | 947079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0484   |
# |    n_updates        | 211769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35988    |
# |    fps              | 166      |
# |    time_elapsed     | 5678     |
# |    total_timesteps  | 947337   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0525   |
# |    n_updates        | 211834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35992    |
# |    fps              | 166      |
# |    time_elapsed     | 5680     |
# |    total_timesteps  | 947581   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.05     |
# |    n_updates        | 211895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 35996    |
# |    fps              | 166      |
# |    time_elapsed     | 5680     |
# |    total_timesteps  | 947706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 211926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36000    |
# |    fps              | 166      |
# |    time_elapsed     | 5682     |
# |    total_timesteps  | 947965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 211991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.01e+03 |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36004    |
# |    fps              | 166      |
# |    time_elapsed     | 5683     |
# |    total_timesteps  | 948125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 212031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36008    |
# |    fps              | 166      |
# |    time_elapsed     | 5684     |
# |    total_timesteps  | 948365   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 212091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36012    |
# |    fps              | 166      |
# |    time_elapsed     | 5685     |
# |    total_timesteps  | 948563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0583   |
# |    n_updates        | 212140   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36016    |
# |    fps              | 166      |
# |    time_elapsed     | 5686     |
# |    total_timesteps  | 948730   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 212182   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36020    |
# |    fps              | 166      |
# |    time_elapsed     | 5687     |
# |    total_timesteps  | 948815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0414   |
# |    n_updates        | 212203   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36024    |
# |    fps              | 166      |
# |    time_elapsed     | 5688     |
# |    total_timesteps  | 949021   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0616   |
# |    n_updates        | 212255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 31.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36028    |
# |    fps              | 166      |
# |    time_elapsed     | 5689     |
# |    total_timesteps  | 949190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0602   |
# |    n_updates        | 212297   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36032    |
# |    fps              | 166      |
# |    time_elapsed     | 5690     |
# |    total_timesteps  | 949315   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 212328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36036    |
# |    fps              | 166      |
# |    time_elapsed     | 5691     |
# |    total_timesteps  | 949528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0588   |
# |    n_updates        | 212381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 992      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36040    |
# |    fps              | 166      |
# |    time_elapsed     | 5692     |
# |    total_timesteps  | 949690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0631   |
# |    n_updates        | 212422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 992      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36044    |
# |    fps              | 166      |
# |    time_elapsed     | 5693     |
# |    total_timesteps  | 949921   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0627   |
# |    n_updates        | 212480   |
# ----------------------------------
# Eval num_timesteps=950000, episode_reward=30.40 +/- 7.28
# Episode length: 1009.60 +/- 174.56
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.01e+03 |
# |    mean_reward      | 30.4     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 950000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 212499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36048    |
# |    fps              | 166      |
# |    time_elapsed     | 5700     |
# |    total_timesteps  | 950103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0519   |
# |    n_updates        | 212525   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36052    |
# |    fps              | 166      |
# |    time_elapsed     | 5700     |
# |    total_timesteps  | 950227   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 212556   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 990      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36056    |
# |    fps              | 166      |
# |    time_elapsed     | 5702     |
# |    total_timesteps  | 950448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 212611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36060    |
# |    fps              | 166      |
# |    time_elapsed     | 5703     |
# |    total_timesteps  | 950607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 212651   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36064    |
# |    fps              | 166      |
# |    time_elapsed     | 5703     |
# |    total_timesteps  | 950743   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 212685   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36068    |
# |    fps              | 166      |
# |    time_elapsed     | 5705     |
# |    total_timesteps  | 951006   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0421   |
# |    n_updates        | 212751   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36072    |
# |    fps              | 166      |
# |    time_elapsed     | 5706     |
# |    total_timesteps  | 951187   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 212796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 31.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36076    |
# |    fps              | 166      |
# |    time_elapsed     | 5707     |
# |    total_timesteps  | 951448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 212861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36080    |
# |    fps              | 166      |
# |    time_elapsed     | 5709     |
# |    total_timesteps  | 951629   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0738   |
# |    n_updates        | 212907   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36084    |
# |    fps              | 166      |
# |    time_elapsed     | 5710     |
# |    total_timesteps  | 951915   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 212978   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36088    |
# |    fps              | 166      |
# |    time_elapsed     | 5711     |
# |    total_timesteps  | 952052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 213012   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36092    |
# |    fps              | 166      |
# |    time_elapsed     | 5712     |
# |    total_timesteps  | 952234   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0629   |
# |    n_updates        | 213058   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36096    |
# |    fps              | 166      |
# |    time_elapsed     | 5713     |
# |    total_timesteps  | 952367   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0481   |
# |    n_updates        | 213091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36100    |
# |    fps              | 166      |
# |    time_elapsed     | 5714     |
# |    total_timesteps  | 952533   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0909   |
# |    n_updates        | 213133   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36104    |
# |    fps              | 166      |
# |    time_elapsed     | 5715     |
# |    total_timesteps  | 952774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 213193   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36108    |
# |    fps              | 166      |
# |    time_elapsed     | 5717     |
# |    total_timesteps  | 953055   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 213263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36112    |
# |    fps              | 166      |
# |    time_elapsed     | 5718     |
# |    total_timesteps  | 953232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 213307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36116    |
# |    fps              | 166      |
# |    time_elapsed     | 5719     |
# |    total_timesteps  | 953427   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0504   |
# |    n_updates        | 213356   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36120    |
# |    fps              | 166      |
# |    time_elapsed     | 5720     |
# |    total_timesteps  | 953672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0499   |
# |    n_updates        | 213417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36124    |
# |    fps              | 166      |
# |    time_elapsed     | 5722     |
# |    total_timesteps  | 953862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 213465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36128    |
# |    fps              | 166      |
# |    time_elapsed     | 5723     |
# |    total_timesteps  | 954039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0437   |
# |    n_updates        | 213509   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36132    |
# |    fps              | 166      |
# |    time_elapsed     | 5724     |
# |    total_timesteps  | 954304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 213575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36136    |
# |    fps              | 166      |
# |    time_elapsed     | 5725     |
# |    total_timesteps  | 954498   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0735   |
# |    n_updates        | 213624   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36140    |
# |    fps              | 166      |
# |    time_elapsed     | 5726     |
# |    total_timesteps  | 954676   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 213668   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36144    |
# |    fps              | 166      |
# |    time_elapsed     | 5727     |
# |    total_timesteps  | 954850   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 213712   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36148    |
# |    fps              | 166      |
# |    time_elapsed     | 5728     |
# |    total_timesteps  | 955032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 213757   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 997      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36152    |
# |    fps              | 166      |
# |    time_elapsed     | 5729     |
# |    total_timesteps  | 955146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0996   |
# |    n_updates        | 213786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36156    |
# |    fps              | 166      |
# |    time_elapsed     | 5730     |
# |    total_timesteps  | 955288   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 213821   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36160    |
# |    fps              | 166      |
# |    time_elapsed     | 5731     |
# |    total_timesteps  | 955431   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 213857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36164    |
# |    fps              | 166      |
# |    time_elapsed     | 5732     |
# |    total_timesteps  | 955635   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 213908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36168    |
# |    fps              | 166      |
# |    time_elapsed     | 5733     |
# |    total_timesteps  | 955774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0537   |
# |    n_updates        | 213943   |
# ----------------------------------
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0879   |
# |    n_updates        | 223695   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37016    |
# |    fps              | 166      |
# |    time_elapsed     | 5969     |
# |    total_timesteps  | 994919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 223729   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37020    |
# |    fps              | 166      |
# |    time_elapsed     | 5970     |
# |    total_timesteps  | 995055   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0804   |
# |    n_updates        | 223763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37024    |
# |    fps              | 166      |
# |    time_elapsed     | 5970     |
# |    total_timesteps  | 995184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 223795   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37028    |
# |    fps              | 166      |
# |    time_elapsed     | 5972     |
# |    total_timesteps  | 995386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0777   |
# |    n_updates        | 223846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 996      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37032    |
# |    fps              | 166      |
# |    time_elapsed     | 5973     |
# |    total_timesteps  | 995608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 223901   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37036    |
# |    fps              | 166      |
# |    time_elapsed     | 5974     |
# |    total_timesteps  | 995744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0504   |
# |    n_updates        | 223935   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37040    |
# |    fps              | 166      |
# |    time_elapsed     | 5975     |
# |    total_timesteps  | 995862   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 223965   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37044    |
# |    fps              | 166      |
# |    time_elapsed     | 5975     |
# |    total_timesteps  | 996018   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0663   |
# |    n_updates        | 224004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37048    |
# |    fps              | 166      |
# |    time_elapsed     | 5977     |
# |    total_timesteps  | 996242   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0335   |
# |    n_updates        | 224060   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37052    |
# |    fps              | 166      |
# |    time_elapsed     | 5978     |
# |    total_timesteps  | 996456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 224113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 999      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37056    |
# |    fps              | 166      |
# |    time_elapsed     | 5979     |
# |    total_timesteps  | 996688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0716   |
# |    n_updates        | 224171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37060    |
# |    fps              | 166      |
# |    time_elapsed     | 5980     |
# |    total_timesteps  | 996852   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0932   |
# |    n_updates        | 224212   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1e+03    |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37064    |
# |    fps              | 166      |
# |    time_elapsed     | 5981     |
# |    total_timesteps  | 996932   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 224232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 995      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37068    |
# |    fps              | 166      |
# |    time_elapsed     | 5982     |
# |    total_timesteps  | 997126   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0674   |
# |    n_updates        | 224281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37072    |
# |    fps              | 166      |
# |    time_elapsed     | 5983     |
# |    total_timesteps  | 997369   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0427   |
# |    n_updates        | 224342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37076    |
# |    fps              | 166      |
# |    time_elapsed     | 5984     |
# |    total_timesteps  | 997538   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0828   |
# |    n_updates        | 224384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37080    |
# |    fps              | 166      |
# |    time_elapsed     | 5985     |
# |    total_timesteps  | 997669   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 224417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37084    |
# |    fps              | 166      |
# |    time_elapsed     | 5986     |
# |    total_timesteps  | 997898   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0305   |
# |    n_updates        | 224474   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 994      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37088    |
# |    fps              | 166      |
# |    time_elapsed     | 5987     |
# |    total_timesteps  | 998052   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.076    |
# |    n_updates        | 224512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 998      |
# |    ep_rew_mean      | 32.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37092    |
# |    fps              | 166      |
# |    time_elapsed     | 5989     |
# |    total_timesteps  | 998257   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 224564   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 993      |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37096    |
# |    fps              | 166      |
# |    time_elapsed     | 5989     |
# |    total_timesteps  | 998362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 224590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37100    |
# |    fps              | 166      |
# |    time_elapsed     | 5990     |
# |    total_timesteps  | 998468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 224616   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 987      |
# |    ep_rew_mean      | 31.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37104    |
# |    fps              | 166      |
# |    time_elapsed     | 5991     |
# |    total_timesteps  | 998650   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 224662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37108    |
# |    fps              | 166      |
# |    time_elapsed     | 5992     |
# |    total_timesteps  | 998879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 224719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 991      |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37112    |
# |    fps              | 166      |
# |    time_elapsed     | 5993     |
# |    total_timesteps  | 999022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0734   |
# |    n_updates        | 224755   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 989      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37116    |
# |    fps              | 166      |
# |    time_elapsed     | 5994     |
# |    total_timesteps  | 999195   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0558   |
# |    n_updates        | 224798   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37120    |
# |    fps              | 166      |
# |    time_elapsed     | 5995     |
# |    total_timesteps  | 999340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0416   |
# |    n_updates        | 224834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 988      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37124    |
# |    fps              | 166      |
# |    time_elapsed     | 5996     |
# |    total_timesteps  | 999565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.111    |
# |    n_updates        | 224891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 990      |
# |    ep_rew_mean      | 31.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 37128    |
# |    fps              | 166      |
# |    time_elapsed     | 5997     |
# |    total_timesteps  | 999758   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0662   |
# |    n_updates        | 224939   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=28.20 +/- 12.37
# Episode length: 845.20 +/- 138.25
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 845      |
# |    mean_reward      | 28.2     |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0666   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/ALE-Breakout-v5_2

# %%
# !python -m rl_zoo3.record_video --algo dqn --env ALE/Breakout-v5 --n-timesteps 5000 --folder logs/
# Out:
# 2025-03-15 19:23:33.582072: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-15 19:23:33.600810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742066613.623213   32621 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742066613.630046   32621 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-15 19:23:33.652593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading latest experiment, id=2
# Loading logs/dqn/ALE-Breakout-v5_2/ALE-Breakout-v5.zip
# A.L.E: Arcade Learning Environment (version 0.10.2+c9d4b19)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/ALE-Breakout-v5_2/ALE-Breakout-v5.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /content/logs/dqn/ALE-Breakout-v5_2/videos/final-model-dqn-ALE-Breakout-v5-step-0-to-step-5000.mp4
# Moviepy - Building video /content/logs/dqn/ALE-Breakout-v5_2/videos/final-model-dqn-ALE-Breakout-v5-step-0-to-step-5000.mp4.
# Moviepy - Writing video /content/logs/dqn/ALE-Breakout-v5_2/videos/final-model-dqn-ALE-Breakout-v5-step-0-to-step-5000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /content/logs/dqn/ALE-Breakout-v5_2/videos/final-model-dqn-ALE-Breakout-v5-step-0-to-step-5000.mp4
